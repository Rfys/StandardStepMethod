# %%
import StandardStepMethod as ssm
import matplotlib.pyplot as plt

# %%
profile1 = ssm.uniformChannel(
    Discharge = 6, 
    Slope = 0.002, 
    Base = 1, 
    Manning = 0.025, 
    M1 = 1, 
    M2 = 1, 
    Boundary_Depth = 3, 
    Initial_x = 0, 
    delta_x = 10, 
    Final_x = 2000, 
    BaseDepthAtBoundary = 0, 
    Direction = 1
)
# Out:
#             ***  Standard Step Method - Water Profile Analysis  ***
#                      coded by: Arif Yunando S - 2017410211
#  Applied Hydraulics - Civil Engineering Dept. - Parahyangan Catholic University
# --------------------------------------------------------------------------------
# Discharge Rate           : 6
# Channel Slope            : 0.002
# Channel Base Width       : 1
# Manning Coefficient      : 0.025
# Left Slope               : 1
# Right Slope              : 1
# Water Depth at Boundary  : 3
# Initial X Position       : 0
# Delta X Position         : 10
# Final X position         : 2000
# Base Position at Boundary: 0
# Direction                : Upstream
# --------------------------------------------------------------------------------

# %%
ssm.createPlot(profile1)

# %%
profile1
# Out:
#      Energy Slope  Spesific Energy  X Position  Stream Depth (Y)  \
# 0        0.000114         3.012742         0.0          3.000000
# 1        0.000118         2.993901       -10.0          2.980871
# 2        0.000121         2.975095       -20.0          2.961769
# 3        0.000125         2.956326       -30.0          2.942695
# 4        0.000129         2.937594       -40.0          2.923650
# ..            ...              ...         ...               ...
# 195      0.002000         1.690954     -1950.0          1.580688
# 196      0.002000         1.690950     -1960.0          1.580683
# 197      0.002000         1.690946     -1970.0          1.580678
# 198      0.002000         1.690942     -1980.0          1.580673
# 199      0.002000         1.690939     -1990.0          1.580669
#
#      Normal Depth (Yn)  Critical Depth (Yc)  Base Depth  Y Position  \
# 0             1.580649             1.086345        0.00    3.000000
# 1             1.580649             1.086345        0.02    3.000871
# 2             1.580649             1.086345        0.04    3.001769
# 3             1.580649             1.086345        0.06    3.002695
# 4             1.580649             1.086345        0.08    3.003650
# ..                 ...                  ...         ...         ...
# 195           1.580649             1.086345        3.90    5.480688
# 196           1.580649             1.086345        3.92    5.500683
# 197           1.580649             1.086345        3.94    5.520678
# 198           1.580649             1.086345        3.96    5.540673
# 199           1.580649             1.086345        3.98    5.560669
#
#      Yn Position  Yc Position
# 0       1.580649     1.086345
# 1       1.600649     1.106345
# 2       1.620649     1.126345
# 3       1.640649     1.146345
# 4       1.660649     1.166345
# ..           ...          ...
# 195     5.480649     4.986345
# 196     5.500649     5.006345
# 197     5.520649     5.026345
# 198     5.540649     5.046345
# 199     5.560649     5.066345
#
# [200 rows x 10 columns]
