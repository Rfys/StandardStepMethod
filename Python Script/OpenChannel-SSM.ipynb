# %%
'''
---
All codes are availabel in StandardStepMethod Module
To use it, please copy the file into your project folder and import it
---
Importing Matplotlib to configure the result to your desire is also suggested
---
'''

import StandardStepMethod as ssm
import matplotlib.pyplot as plt

# %%
'''
There are 2 functions wrapper that you can use
First one is Calc_NormalCriticalDepth that return Normal Depth and Critical Depth
of a channel with known discharge and channel characteristic
Below is the example of the wrapper usage
'''


Yc, Yn = ssm.Calc_NormalCriticalDepth(
    discharge = 6, 
    base_width = 1, 
    left_slope = 1, 
    right_slope = 1, 
    manning = 0.025, 
    slope = 0.002
)
# Out:
#             ***  Normal & Critical Depth - Water Profile Analysis  ***
#                       coded by: Arif Yunando S - 2017410211
#   Applied Hydraulics - Civil Engineering Dept. - Parahyangan Catholic University
# -----------------------------------------------------------------------------------
#      Discharge Rate           : 6
#      Channel Base Width       : 1
#      Left Slope               : 1
#      Right Slope              : 1
#      Manning Coefficient      : 0.025
#      Channel Slope            : 0.002
# -----------------------------------------------------------------------------------
#      Normal Depth (Yn)        : 1.581
#      Critical Depth (Yc)      : 1.086
# -----------------------------------------------------------------------------------

# %%
'''
The second on is UniformChannel
This wrapper gives you the water profile alongside with its normal depth and critical depth with same channel characteristic throughout the stream
Here an example of its usage
'''

profile1 = ssm.uniformChannel(
    Discharge = 6, 
    Slope = 0.002, 
    Base = 1, 
    Manning = 0.025, 
    M1 = 1, 
    M2 = 1, 
    Boundary_Depth = 1.1, 
    Initial_x = 0, 
    delta_x = 1, 
    Distance = 250, 
    BaseDepthAtBoundary = 0, 
    Direction = 1
)

profile1
# Out:
#             ***  Standard Step Method - Water Profile Analysis  ***
#                      coded by: Arif Yunando S - 2017410211
#  Applied Hydraulics - Civil Engineering Dept. - Parahyangan Catholic University
# --------------------------------------------------------------------------------
#      Discharge Rate           : 6
#      Channel Slope            : 0.002
#      Channel Base Width       : 1
#      Manning Coefficient      : 0.025
#      Left Slope               : 1
#      Right Slope              : 1
#      Water Depth at Boundary  : 1.1
#      Initial X Position       : 0
#      Delta X                  : 1
#      Distance                 : 250
#      Base Position at Boundary: 0
#      Direction                : Upstream
# --------------------------------------------------------------------------------
#      Energy Slope  Spesific Energy  X Position  Stream Depth (Y)  \
# 0        0.009094         1.443858         0.0          1.100000
# 1        0.007578         1.450195        -1.0          1.150250
# 2        0.006987         1.455477        -2.0          1.173240
# 3        0.006583         1.460263        -3.0          1.190342
# 4        0.006273         1.464691        -4.0          1.204360
# ..            ...              ...         ...               ...
# 246      0.002183         1.666417      -246.0          1.548631
# 247      0.002182         1.666599      -247.0          1.548872
# 248      0.002180         1.666780      -248.0          1.549111
# 249      0.002179         1.666960      -249.0          1.549349
# 250      0.002177         1.667138      -250.0          1.549584
#
#      Normal Depth (Yn)  Critical Depth (Yc)  Base Depth  Y Position  \
# 0             1.580649             1.086345       0.000    1.100000
# 1             1.580649             1.086345       0.002    1.152250
# 2             1.580649             1.086345       0.004    1.177240
# 3             1.580649             1.086345       0.006    1.196342
# 4             1.580649             1.086345       0.008    1.212360
# ..                 ...                  ...         ...         ...
# 246           1.580649             1.086345       0.492    2.040631
# 247           1.580649             1.086345       0.494    2.042872
# 248           1.580649             1.086345       0.496    2.045111
# 249           1.580649             1.086345       0.498    2.047349
# 250           1.580649             1.086345       0.500    2.049584
#
#      Yn Position  Yc Position
# 0       1.580649     1.086345
# 1       1.582649     1.088345
# 2       1.584649     1.090345
# 3       1.586649     1.092345
# 4       1.588649     1.094345
# ..           ...          ...
# 246     2.072649     1.578345
# 247     2.074649     1.580345
# 248     2.076649     1.582345
# 249     2.078649     1.584345
# 250     2.080649     1.586345
#
# [251 rows x 10 columns]

# %%
'''
There's also additional plt.plot wrapper to build the graph quickly
Here's the example:
'''


ssm.createPlot(profile1, fig_width=15, fig_heigth=5)

# %%
profile2 = ssm.uniformChannel(
    Discharge = 6, 
    Slope = 0.08, 
    Base = 1, 
    Manning = 0.025, 
    M1 = 1, 
    M2 = 1, 
    Boundary_Depth = 1.065, 
    Initial_x = 0, 
    delta_x = 0.01, 
    Distance = 200, 
    BaseDepthAtBoundary = 0, 
    Direction = -1
)

profile2
# Out:
#             ***  Standard Step Method - Water Profile Analysis  ***
#                      coded by: Arif Yunando S - 2017410211
#  Applied Hydraulics - Civil Engineering Dept. - Parahyangan Catholic University
# --------------------------------------------------------------------------------
#      Discharge Rate           : 6
#      Channel Slope            : 0.08
#      Channel Base Width       : 1
#      Manning Coefficient      : 0.025
#      Left Slope               : 1
#      Right Slope              : 1
#      Water Depth at Boundary  : 1.065
#      Initial X Position       : 0
#      Delta X                  : 0.01
#      Distance                 : 200
#      Base Position at Boundary: 0
#      Direction                : Downstream
# --------------------------------------------------------------------------------
#        Energy Slope  Spesific Energy  X Position  Stream Depth (Y)  \
# 0          0.010371         1.444371        0.00          1.065000
# 1          0.010666         1.445066        0.01          1.057643
# 2          0.010903         1.445758        0.02          1.051918
# 3          0.011107         1.446448        0.03          1.047086
# 4          0.011291         1.447136        0.04          1.042841
# ...             ...              ...         ...               ...
# 19996      0.080007         2.362105      199.96          0.631189
# 19997      0.080007         2.362105      199.97          0.631189
# 19998      0.080007         2.362105      199.98          0.631189
# 19999      0.080007         2.362105      199.99          0.631189
# 20000      0.080007         2.362105      200.00          0.631189
#
#        Normal Depth (Yn)  Critical Depth (Yc)  Base Depth  Y Position  \
# 0               0.631203             1.086345      0.0000    1.065000
# 1               0.631203             1.086345     -0.0008    1.056843
# 2               0.631203             1.086345     -0.0016    1.050318
# 3               0.631203             1.086345     -0.0024    1.044686
# 4               0.631203             1.086345     -0.0032    1.039641
# ...                  ...                  ...         ...         ...
# 19996           0.631203             1.086345    -15.9968  -15.365611
# 19997           0.631203             1.086345    -15.9976  -15.366411
# 19998           0.631203             1.086345    -15.9984  -15.367211
# 19999           0.631203             1.086345    -15.9992  -15.368011
# 20000           0.631203             1.086345    -16.0000  -15.368811
#
#        Yn Position  Yc Position
# 0         0.631203     1.086345
# 1         0.630403     1.085545
# 2         0.629603     1.084745
# 3         0.628803     1.083945
# 4         0.628003     1.083145
# ...            ...          ...
# 19996   -15.365597   -14.910455
# 19997   -15.366397   -14.911255
# 19998   -15.367197   -14.912055
# 19999   -15.367997   -14.912855
# 20000   -15.368797   -14.913655
#
# [20001 rows x 10 columns]

# %%
ssm.createPlot(profile2)
plt.xlim(0,15)
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
'''
The createPlot wrapper can also accept more than one analysis in an array like structure such as below
'''

ssm.createPlot([profile1, profile2])
plt.xlim(-20, 20)
plt.ylim(-1, 2)
plt.savefig("img.jpg")
